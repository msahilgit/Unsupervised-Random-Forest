# %%
import numpy as np
import copy as cp
import matplotlib as mt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator
import matplotlib.pyplot as plt
import pyemma.plots as mplt 
import pyemma
import pickle as pkl
import sklearn as skl
import sklearn.metrics as mtr
import scipy as sc
import sys
from tqdm import tqdm

# %%
vall = np.load('saved_vamp/vamps_all.npy')

# %%
vall.shape
# Out:
# (755, 10, 3, 2)

# %%
fsupervised = [np.load(f'saved_supervised/fimp_supervised_{i}.npy') for i in range(5)]
fsupervised = np.mean(fsupervised, axis=0), np.std(fsupervised, axis=0)

# %%
fpermute = [
    [
        np.load(f'saved_furf/fimp_hlabel{h}_{i}.npy')
    for i in range(5)]
for h in range(2,11)]
fpermute = np.mean(fpermute, axis=1), np.std(fpermute, axis=1)

# %%
fmarginal = [
    [
        np.load(f'saved_synthetic_marginal/fimp_hlabel{h}_{i}.npy')
    for i in range(5)]
for h in range(2,11)]
fmarginal = np.mean(fmarginal, axis=1), np.std(fmarginal, axis=1)

# %%
frandom = [
    [
        np.load(f'saved_synthetic_random/fimp_hlabel{h}_{i}.npy')
    for i in range(5)]
for h in range(2,11)]
frandom = np.mean(frandom, axis=1), np.std(frandom, axis=1)

# %%
fnonsense = [
    [
        np.load(f'saved_synthetic_nonsense/fimp_hlabel{h}_{i}.npy')
    for i in range(5)]
for h in range(2,11)]
fnonsense = np.mean(fnonsense, axis=1), np.std(fnonsense, axis=1)

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], fpermute[0][0])

# %%
cmaps = mt.cm.get_cmap('Reds')
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], fpermute[0][0], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
# Out:
# (0.0, 0.08)

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], fsupervised[0])

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], fmarginal[0][0])

# %%
fig,ax=plt.subplots(1,2, figsize=(8,3), sharey=True)
ax[0].scatter(vall[:,0,0,0], fmarginal[0][0])
ax[1].scatter(vall[:,0,0,0], fmarginal[0][4])

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], fmarginal[0][2])

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], frandom[0][0])

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], frandom[0][2])

# %%
fig = plt.figure(figsize=(16,9))
for m in range(3):
    ax = fig.add_subplot(131+m, projection='3d')
    for l in range(10):
        ax.scatter(vall[:,l,m,0], [5*(l+1) for i in range(755)], fnonsense[0][0])

# %%
fig,ax=plt.subplots(3,2,figsize=(8,8), sharex=True, sharey=True)
ax[0,0].scatter(vall[:,0,0,0], fpermute[0][0])
ax[0,1].scatter(vall[:,0,0,0], fnonsense[0][0])
ax[1,0].scatter(vall[:,0,0,0], fmarginal[0][0])
ax[1,1].scatter(vall[:,0,0,0], fmarginal[0][4])
ax[2,0].scatter(vall[:,0,0,0], frandom[0][0])
ax[2,1].scatter(vall[:,0,0,0], frandom[0][2])

# %%
fig,ax=plt.subplots(3,2,figsize=(8,8), sharex=True, sharey=True)
ax[0,0].scatter(vall[:,0,1,0], fpermute[0][0])
ax[0,1].scatter(vall[:,0,1,0], fnonsense[0][0])
ax[1,0].scatter(vall[:,0,1,0], fmarginal[0][0])
ax[1,1].scatter(vall[:,0,1,0], fmarginal[0][4])
ax[2,0].scatter(vall[:,0,1,0], frandom[0][0])
ax[2,1].scatter(vall[:,0,1,0], frandom[0][2])

# %%
cmaps = mt.cm.get_cmap('Reds')
# Out:
# /tmp/ipykernel_1831855/4104700905.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmaps = mt.cm.get_cmap('Reds')

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               fpermute[0][0], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               fnonsense[0][0], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               fmarginal[0][0], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               fmarginal[0][4], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               frandom[0][0], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig = plt.figure(figsize=(9,9))
ax0 = fig.add_subplot(projection='3d')
for i in range(10):ax0.scatter(vall[:,i,0,0], [5*(i+1) for j in range(755)], 
                               frandom[0][2], color=cmaps((i+3)/13))
ax0.set_zlim(0,0.08)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], fpermute[0][0]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_permute2.png', transparent=True)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], fnonsense[0][0]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_nonsense2.png', transparent=True)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], fmarginal[0][0]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_marginal2.png', transparent=True)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], fmarginal[0][4]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_marginal6.png', transparent=True)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], frandom[0][0]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_random2.png', transparent=True)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(7,6))
ax.scatter(vall[:,0,1,0], frandom[0][2]*100, s=80, c='crimson')
ax.set_ylim(-0.14,8)
ax.set_yticks([0,4,8])
ax.set_xticks([1,1.5,2])
ax.set_xlim(1,2)
ax.spines[:].set_linewidth(2)
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(labelsize=22, length=7, width=2, top=True)
ax.tick_params(which='minor', length=4, width=2)
plt.savefig(f'plots/vamp2_random4.png', transparent=True)
plt.show()
