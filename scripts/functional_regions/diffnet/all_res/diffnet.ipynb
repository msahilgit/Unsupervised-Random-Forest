# %%
import numpy as np
import os
from diffnets import utils
import pickle
from collections import defaultdict
import matplotlib.pyplot as plt
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
whitened_dir = "2_processed_data/whitened_data"

# %% [markdown]
# ## 0111

# %% [markdown]
# ### 8

# %%
nn_dir = '3_ss_sae_1_0111/latent8'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 6.401393

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### 32

# %%
nn_dir = '3_ss_sae_1_0111/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.8886625

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### 64

# %%
nn_dir = '3_ss_sae_1_0111/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 1.2994165

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 0100

# %% [markdown]
# ### 8

# %%
nn_dir = '3_ss_sae_2_0100/latent8'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 2.939291

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### 32

# %%
nn_dir = '3_ss_sae_2_0100/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.93404144

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### 64

# %%
nn_dir = '3_ss_sae_2_0100/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.879265

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()
