# %%
import numpy as np
import os
from diffnets import utils
import pickle
from collections import defaultdict
import matplotlib.pyplot as plt
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
whitened_dir = "2_processed_data/whitened_data"

# %% [markdown]
# # n_latent

# %% [markdown]
# ## 32

# %%
nn_dir = '4_ss_split_sae_1/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 9.36495

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '4_ss_split_sae_1/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 99.383675

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 96

# %%
nn_dir = '4_ss_split_sae_1/latent96'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 82.790886

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 128

# %%
nn_dir = '4_ss_split_sae_1/latent128'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 56.595165

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# # more_epochs

# %% [markdown]
# ## 32

# %%
nn_dir = '4_ss_split_sae_2_more_epochs/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 86.22778

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '4_ss_split_sae_2_more_epochs/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 260.06055

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 96

# %%
nn_dir = '4_ss_split_sae_2_more_epochs/latent96'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 194.0681

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 128

# %%
nn_dir = '4_ss_split_sae_2_more_epochs/latent128'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 546.42

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## reduced latent as suggested by Mick

# %% [markdown]
# ### n_latent = 8

# %%
nn_dir = '4_ss_split_sae_1/latent8'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 67.28326

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### 2

# %%
nn_dir = '4_ss_split_sae_1/latent2'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 1217.9766

# %% [markdown]
# # act map = 0111

# %% [markdown]
# ## 32

# %%
nn_dir = '4_ss_split_sae_1/latent32_0111/'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 31.220028

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '4_ss_split_sae_1/latent64_0111/'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 129.82874

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()
