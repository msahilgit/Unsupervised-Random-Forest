# %%
import numpy as np
import os
from diffnets import utils
import pickle
from collections import defaultdict
import matplotlib.pyplot as plt
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
whitened_dir = "2_processed_data/whitened_data"

# %% [markdown]
# # n_latent

# %% [markdown]
# ## 32

# %%
nn_dir = '3_ss_sae_1/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 1.1345584

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '3_ss_sae_1/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 3.3924775

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 96

# %%
nn_dir = '3_ss_sae_1/latent96'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 4.243341

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 128

# %%
nn_dir = '3_ss_sae_1/latent128'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 4.1169643

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# # epoch = 100

# %% [markdown]
# ## 32

# %%
nn_dir = '3_ss_sae_2_more_epochs/latent32'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 38.058884

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '3_ss_sae_2_more_epochs/latent64'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 69.454704

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 96

# %%
nn_dir = '3_ss_sae_2_more_epochs/latent96'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 27.725794

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 128

# %%
nn_dir = '3_ss_sae_2_more_epochs/latent128'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 173.6221

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## reduced latent as suggested by Mick

# %% [markdown]
# ### n_latent = 8

# %%
nn_dir = '3_ss_sae_1/latent8'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 4.2736144

# %%
loss = [np.load(f'{nn_dir}/test_loss_{i}.npy') for i in [2,3,'polish']]
for i in loss: plt.plot(i)

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ### n_latent = 2

# %%
nn_dir = '3_ss_sae_1/latent2'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 20.160456

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# # act_map = 0, 1, 1, 1

# %% [markdown]
# ## n_latent=32

# %%
nn_dir = '3_ss_sae_1/latent32_0111/'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.21557356

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## n_latent=8

# %%
nn_dir = '3_ss_sae_1/latent8_0111/'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.56287915

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()

# %% [markdown]
# ## 64

# %%
nn_dir = '3_ss_sae_1/latent64_0111/'
rmsd = np.load(f'{nn_dir}/rmsd.npy')
print(np.mean(rmsd))
plt.plot(rmsd)
# Out:
# 0.33861345

# %%
lab_fns = utils.get_fns(os.path.join(nn_dir,"labels"),"*.npy")
traj_d_path = os.path.join(whitened_dir,"traj_dict.pkl")
traj_d = pickle.load(open(traj_d_path, 'rb'))
lab_v = defaultdict(list)
for key,item in traj_d.items():
    for traj_ind in range(item[0],item[1]):
        lab = np.load(lab_fns[traj_ind])
        lab_v[key].append(lab)
        
plt.figure(figsize=(8,6))
axes = plt.gca()
lw = 8

leg_labels = []
for k in traj_d.keys():
    t = np.concatenate(lab_v[k])
    n, x = np.histogram(t, range=(0, 1), bins=50)
    leg_labels.append(k.split("/")[-1])
    plt.plot(x[:-1],n,label=k,linewidth=lw)
plt.show()
