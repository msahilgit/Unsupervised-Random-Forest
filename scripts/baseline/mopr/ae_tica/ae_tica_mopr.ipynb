# %%
import copy as cp
import numpy as np
import matplotlib as mt
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MaxNLocator

# %%
paths = [
    'saved_relu_ae1',
    'saved_relu_ae2/',
    'saved_relu_ae3/',
    'saved_tanh_ae1/',
    'saved_tanh_ae2/',
    'saved_tanh_ae3/'
]

# %%
loss = [
    [
        np.load(f'{p}/loss_{i}.npy')
    for i in range(5)]
for p in paths]

# %%
vloss = [
    [
        np.load(f'{p}/val_loss_{i}.npy')
    for i in range(5)]
for p in paths]

# %%
colors = ['green', 'darkturquoise', 'indianred', 'blueviolet', 'gray']

# %%
nn=6

fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.08)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.04,0.08])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(which='minor', length=5, width=2)
#
for a,curve in enumerate(loss[nn-1]): ax.plot(curve, lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/loss_nn{nn}.png', transparent=True)
plt.show()

# %%
nn=6

fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.08)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.04,0.08])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(which='minor', length=5, width=2)
#
for a,curve in enumerate(vloss[nn-1]): ax.plot(curve, lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/vloss_nn{nn}.png', transparent=True)
plt.show()
