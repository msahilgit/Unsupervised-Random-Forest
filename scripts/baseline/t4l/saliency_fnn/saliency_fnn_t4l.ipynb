# %%
import copy as cp
import numpy as np
import matplotlib as mt
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MaxNLocator

# %%
colors = ['green', 'darkturquoise', 'indianred', 'blueviolet', 'gray']

# %%
loss1 = [np.load(f'saved_nn6/loss_{i}.npy') for i in range(5)]
vloss1 = [np.load(f'saved_nn6/val_loss_{i}.npy') for i in range(5)]
accu1 = [np.load(f'saved_nn6/accuracy_{i}.npy') for i in range(5)]
vaccu1 = [np.load(f'saved_nn6/val_accuracy_{i}.npy') for i in range(5)]

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.6)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.3,0.6])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(3))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(loss1[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/loss1.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.6)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.3,0.6])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(3))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(vloss1[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/vloss1.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0.7,1)
ax.set_xticks([0,100,200])
ax.set_yticks([0.7,0.8,0.9,1])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(accu1[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/accu1.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0.7,1)
ax.set_xticks([0,100,200])
ax.set_yticks([0.7,0.8,0.9,1])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(vaccu1[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/vaccu1.png', transparent=True)
plt.show()

# %%
loss2 = [np.load(f'saved_l1_nn1_0.001/loss_{i}.npy') for i in range(5)]
vloss2 = [np.load(f'saved_l1_nn1_0.001/val_loss_{i}.npy') for i in range(5)]
accu2 = [np.load(f'saved_l1_nn1_0.001/accuracy_{i}.npy') for i in range(5)]
vaccu2 = [np.load(f'saved_l1_nn1_0.001/val_accuracy_{i}.npy') for i in range(5)]

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.6)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.3,0.6])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(3))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(loss2[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/loss2.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0,0.6)
ax.set_xticks([0,100,200])
ax.set_yticks([0,0.3,0.6])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(3))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(vloss2[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/vloss2.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0.7,1)
ax.set_xticks([0,100,200])
ax.set_yticks([0.7,0.8,0.9,1])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(accu2[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/accu2.png', transparent=True)
plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(5,6))
ax.spines[:].set_linewidth(2)
ax.set_xlim(-5,201)
ax.set_ylim(0.7,1)
ax.set_xticks([0,100,200])
ax.set_yticks([0.7,0.8,0.9,1])
ax.tick_params(length=8, width=2, labelsize=24)
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.tick_params(which='minor', length=5, width=2)
#
for a in range(5): ax.plot(vaccu2[a], lw=2, color=colors[a])
#
plt.savefig(f'saved_plots/vaccu2.png', transparent=True)
plt.show()
