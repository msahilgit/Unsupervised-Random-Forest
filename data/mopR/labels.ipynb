# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dists = np.load('distance_alldata.npy', allow_pickle=True)

# %%
dists = np.concatenate((dists))

# %%
bins = np.arange(np.min(dists), np.max(dists), 0.01)
xb = bins[:-1] + (bins[1]-bins[0])/2

# %%
hist, _ = np.histogram(dists, bins=bins, density=True)

# %%
plt.figure(figsize=(16,3))
plt.plot(xb, hist)
plt.xlim(0,1)
plt.ylim(0,1)
plt.plot([0,5],[0,0])
plt.xticks([0,0.3,0.35,0.4,1])
# Out:
# ([<matplotlib.axis.XTick at 0x7ff4f7898b80>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
labels = np.zeros(dists.shape)
labels[ np.where( (dists > 0.35) & (dists <1) )[0] ] = 1
labels[ np.where( dists >= 1 )[0] ] = 2

# %%
np.save('labels.npy', labels)

# %%
plt.figure(figsize=(16,3))
plt.plot(dists[4])
# plt.xlim(0,70000)

# %%
time=[70000, -1, 80000, 65000, 75000, 45000, 125000]

# %%
dd = [dists[i][:time[i]] for i in range(7)]

# %%
np.savez('prconf2_bplig.npz', *dd)

# %%
dd = np.concatenate(( dd ))

# %%
np.where(dd<0.8)[0].shape[0]/dd.shape[0]
# Out:
# 0.10234140998564141

# %%
bins = np.arange(np.min(dd), np.max(dd), 0.01)
xb = bins[:-1] + (bins[1]-bins[0])/2

# %%
h,_=np.histogram(dd,bins=bins)

# %%
plt.figure(figsize=(16,3))
plt.plot(xb,h)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)
